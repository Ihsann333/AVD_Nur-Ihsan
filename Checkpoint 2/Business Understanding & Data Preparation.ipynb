# %% [markdown]
# https://www.kaggle.com/datasets/mohamedhanyyy/top-football-leagues-scorers/data

# %% [markdown]
# ## Business Understanding
# **Business Objective**
# Proyek ini bertujuan untuk mengidentifikasi pola pencetak gol terbaik di liga-liga top dunia serta faktor yang mempengaruhi performa mereka, sehingga klub sepak bola dapat membuat keputusan yang lebih efektif dalam perekrutan pemain dan strategi permainan.
#
# **Assess Situation**
# Klub sepak bola sering mengalami kesulitan dalam menilai performa pencetak gol terbaik secara objektif, yang dapat menyebabkan keputusan transfer yang kurang tepat dan strategi permainan yang tidak optimal. Analisis berbasis data diperlukan untuk memahami pola performa pemain dan mengoptimalkan strategi tim.
#
# **Data Mining Goals**
# Analisis ini akan mengeksplorasi hubungan antara jumlah gol, assist, jumlah pertandingan, dan faktor lain untuk menentukan pola performa pemain, mengelompokkan mereka berdasarkan gaya bermain, serta membangun model prediksi jumlah gol di musim mendatang. Selain itu, sistem rekomendasi berbasis data akan dikembangkan untuk membantu klub dalam memilih pemain yang sesuai dengan kebutuhan tim.
#
# **Project Plan**
# Proyek ini mencakup pemeriksaan dan pembersihan data, analisis pola pencetak gol, clustering pemain, pembuatan model prediksi, serta pengembangan sistem rekomendasi. Hasil analisis akan digunakan untuk mendukung strategi rekrutmen dan optimalisasi performa tim berdasarkan data yang lebih akurat dan objektif.

# %%
import pandas as pd

# %%
data_url = "/content/Top Score.csv"
df = pd.read_csv(data_url)

# %%
output_path = "/content/Top Score.csv"
df.to_csv(output_path, index=False)

print("\nData berhasil disimpan sebagai file Excel:", output_path)
# Out:
# Data berhasil disimpan sebagai file Excel: /content/Top Score.csv

# %%
file_path = "/content/Top Score.csv"

df = pd.read_csv(file_path)
df
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    NaN    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 0               16  1849     11   6.62              0.34     48        20
# 1                0  3129     16  11.86              0.36     88        41
# 2                1  2940     28  23.21              0.75    120        57
# 3                3  2842     13  14.06              0.47    117        42
# 4               10  1745     13  10.65              0.58     50        23
# ..             ...   ...    ...    ...               ...    ...       ...
# 655              0  2155     10   7.49              0.33     50        18
# 656              2  1573     12   9.77              0.59     56        30
# 657              0  2363      7   5.72              0.23     45        14
# 658              0  2461     15  14.51              0.56     84        43
# 659             11  1557      7   4.43              0.27     38        15
#
#      Shots Per Avg Match  On Target Per Avg Match  Year
# 0                   2.47                     1.03  2016
# 1                   2.67                     1.24  2016
# 2                   3.88                     1.84  2016
# 3                   3.91                     1.40  2016
# 4                   2.72                     1.25  2016
# ..                   ...                      ...   ...
# 655                 2.20                     0.79  2020
# 656                 3.38                     1.81  2020
# 657                 1.81                     0.56  2020
# 658                 3.24                     1.66  2020
# 659                 2.32                     0.92  2020
#
# [660 rows x 15 columns]

# %%
print("\nInfo Dataset:")
df.info()

print("\nJumlah baris dan kolom:", df.shape)
# Out:
# Info Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  660 non-null    object
#  1   League                   660 non-null    object
#  2   Club                     626 non-null    object
#  3   Player Names             660 non-null    object
#  4   Matches_Played           660 non-null    int64
#  5   Substitution             660 non-null    int64
#  6   Mins                     660 non-null    int64
#  7   Goals                    660 non-null    int64
#  8   xG                       660 non-null    float64
#  9   xG Per Avg Match         660 non-null    float64
#  10  Shots                    660 non-null    int64
#  11  OnTarget                 660 non-null    int64
#  12  Shots Per Avg Match      660 non-null    float64
#  13  On Target Per Avg Match  660 non-null    float64
#  14  Year                     660 non-null    int64
# dtypes: float64(4), int64(7), object(4)
# memory usage: 77.5+ KB
#
# Jumlah baris dan kolom: (660, 15)

# %%
df.describe()
# Out:
#        Matches_Played  Substitution          Mins       Goals          xG  \
# count      660.000000     660.000000   660.000000  660.000000  660.000000
# mean        22.371212       3.224242  2071.416667   11.784848   10.089606
# std          9.754658       3.839498   900.595049    5.982454    5.724844
# min          2.000000       0.000000   264.000000    2.000000    0.710000
# 25%         14.000000       0.000000  1363.500000    8.000000    6.100000
# 50%         24.000000       2.000000  2245.500000   11.000000    9.285000
# 75%         31.000000       5.000000  2822.000000   14.000000   13.252500
# max         38.000000      26.000000  4177.000000   37.000000   32.540000
#
#        xG Per Avg Match       Shots    OnTarget  Shots Per Avg Match  \
# count        660.000000  660.000000  660.000000           660.000000
# mean           0.476167   64.177273   28.365152             2.948015
# std            0.192831   34.941622   16.363149             0.914906
# min            0.070000    5.000000    2.000000             0.800000
# 25%            0.340000   37.750000   17.000000             2.335000
# 50%            0.435000   62.000000   26.000000             2.845000
# 75%            0.570000   86.000000   37.000000             3.382500
# max            1.350000  208.000000  102.000000             7.200000
#
#        On Target Per Avg Match         Year
# count               660.000000   660.000000
# mean                  1.315652  2018.363636
# std                   0.474239     1.367700
# min                   0.240000  2016.000000
# 25%                   0.980000  2017.000000
# 50%                   1.250000  2019.000000
# 75%                   1.540000  2019.000000
# max                   3.630000  2020.000000

# %%
df.corr(numeric_only=True)
# Out:
#                          Matches_Played  Substitution       Mins     Goals  \
# Matches_Played                 1.000000      -0.080422  0.981231  0.676200
# Substitution                  -0.080422       1.000000  0.006075  0.043922
# Mins                           0.981231       0.006075  1.000000  0.686461
# Goals                          0.676200       0.043922  0.686461  1.000000
# xG                             0.695411       0.004738  0.708465  0.906220
# xG Per Avg Match              -0.163790       0.001942 -0.160581  0.379092
# Shots                          0.788192       0.001490  0.796597  0.834758
# OnTarget                       0.722838       0.007776  0.728925  0.863684
# Shots Per Avg Match           -0.005875       0.009738 -0.011351  0.409114
# On Target Per Avg Match       -0.066603       0.029030 -0.071387  0.431668
# Year                          -0.546415      -0.219274 -0.525116 -0.433296
#
#                                xG  xG Per Avg Match     Shots  OnTarget  \
# Matches_Played           0.695411         -0.163790  0.788192  0.722838
# Substitution             0.004738          0.001942  0.001490  0.007776
# Mins                     0.708465         -0.160581  0.796597  0.728925
# Goals                    0.906220          0.379092  0.834758  0.863684
# xG                       1.000000          0.490747  0.856190  0.852641
# xG Per Avg Match         0.490747          1.000000  0.205135  0.268344
# Shots                    0.856190          0.205135  1.000000  0.923213
# OnTarget                 0.852641          0.268344  0.923213  1.000000
# Shots Per Avg Match      0.420086          0.640633  0.527506  0.487439
# On Target Per Avg Match  0.397934          0.684667  0.391105  0.558326
# Year                    -0.386874          0.074453 -0.469195 -0.512711
#
#                          Shots Per Avg Match  On Target Per Avg Match  \
# Matches_Played                     -0.005875                -0.066603
# Substitution                        0.009738                 0.029030
# Mins                               -0.011351                -0.071387
# Goals                               0.409114                 0.431668
# xG                                  0.420086                 0.397934
# xG Per Avg Match                    0.640633                 0.684667
# Shots                               0.527506                 0.391105
# OnTarget                            0.487439                 0.558326
# Shots Per Avg Match                 1.000000                 0.819838
# On Target Per Avg Match             0.819838                 1.000000
# Year                               -0.063464                -0.132174
#
#                              Year
# Matches_Played          -0.546415
# Substitution            -0.219274
# Mins                    -0.525116
# Goals                   -0.433296
# xG                      -0.386874
# xG Per Avg Match         0.074453
# Shots                   -0.469195
# OnTarget                -0.512711
# Shots Per Avg Match     -0.063464
# On Target Per Avg Match -0.132174
# Year                     1.000000

# %%
output_path = "/content/Top_Football_Scorers.csv"
df.to_csv(output_path, index=False)

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Country                    0.000000
# League                     0.000000
# Club                       5.151515
# Player Names               0.000000
# Matches_Played             0.000000
# Substitution               0.000000
# Mins                       0.000000
# Goals                      0.000000
# xG                         0.000000
# xG Per Avg Match           0.000000
# Shots                      0.000000
# OnTarget                   0.000000
# Shots Per Avg Match        0.000000
# On Target Per Avg Match    0.000000
# Year                       0.000000
# dtype: float64

# %%
df[df['Club'].isnull()]
# Out:
#           Country                          League Club         Player Names  \
# 10          Spain                         La Liga  NaN              Aduriz
# 51        Germany                      Bundesliga  NaN          Mario Gomez
# 82         Brazil  Campeonato Brasileiro S̩rie A  NaN             Robinho
# 83         Brazil  Campeonato Brasileiro S̩rie A  NaN              Kempes
# 85         Brazil  Campeonato Brasileiro S̩rie A  NaN        Bruno Rangel
# 89         Brazil  Campeonato Brasileiro S̩rie A  NaN             Grafite
# 92         Brazil  Campeonato Brasileiro S̩rie A  NaN                Sassa
# 96         Brazil  Campeonato Brasileiro S̩rie A  NaN     Kleber Gladiador
# 97         Brazil  Campeonato Brasileiro S̩rie A  NaN             Pottker
# 98         Brazil  Campeonato Brasileiro S̩rie A  NaN      Jonathan Copete
# 104         Spain                         La Liga  NaN         Rodrigo None
# 149       Germany                      Bundesliga  NaN       Sandro Wagner
# 164        Brazil  Campeonato Brasileiro S̩rie A  NaN        Luiz Fernando
# 171        Brazil  Campeonato Brasileiro S̩rie A  NaN                Dudu
# 175        Brazil  Campeonato Brasileiro S̩rie A  NaN     Henrique Dourado
# 176        Brazil  Campeonato Brasileiro S̩rie A  NaN                Andre
# 177        Brazil  Campeonato Brasileiro S̩rie A  NaN        Edigar Junio
# 178        Brazil  Campeonato Brasileiro S̩rie A  NaN        Junior  Dutra
# 197         Spain                         La Liga  NaN              Charles
# 216         Italy                         Serie A  NaN  Stephan El Shaarawy
# 285        Brazil  Campeonato Brasileiro S̩rie A  NaN      Leandro Damiao
# 289        Brazil  Campeonato Brasileiro S̩rie A  NaN        Roger Guedes
# 290        Brazil  Campeonato Brasileiro S̩rie A  NaN     Leandro Pereira
# 341     Portugal                    Primeira Liga  NaN      Tiquinho Soares
# 344     Portugal                    Primeira Liga  NaN          Alex Telles
# 357     Portugal                    Primeira Liga  NaN          Fabio Abreu
# 359     Portugal                    Primeira Liga  NaN         Alex Telles
# 360     Portugal                    Primeira Liga  NaN        Fabio Martins
# 369     Portugal                    Primeira Liga  NaN          Sandro Lima
# 389         Italy                         Serie A  NaN    Andreas Cornelius
# 460        Brazil  Campeonato Brasileiro S̩rie A  NaN                Dudu
# 471        Brazil  Campeonato Brasileiro S̩rie A  NaN            Everaldo
# 614       England                  Premier League  NaN          Danny Ings
# 658   Netherlands                      Eredivisie  NaN      Cyriel Dessers
#
#      Matches_Played  Substitution   Mins  Goals     xG  xG Per Avg Match  \
# 10               27              5  2480     16  15.92              0.61
# 51               32              1  2950     16  18.32              0.59
# 82               26              4  2234     12   8.00              0.34
# 83               19              7  1684      9   5.85              0.33
# 85               19             12  2016     10   8.91              0.42
# 89               29              2  2511     13  14.01              0.53
# 92               13             13  1412     12  11.15              0.75
# 96               23              1  2143      9   8.35              0.37
# 97               19             12  2007     14   8.66              0.41
# 98               22              3  2147     10   8.14              0.36
# 104              31              6  2770     16  15.45              0.53
# 149              18              7  1666     12  10.00              0.57
# 164              21              7  1792      9   6.04              0.32
# 171              23              3  1751     10   6.82              0.37
# 175              32              0  2472     19  14.83              0.57
# 176              35              0  2931     16  14.81              0.48
# 177              21              5  1547     12  11.40              0.70
# 178              27              3  2022      9  10.43              0.49
# 197              17             17  1861     14  13.91              0.71
# 216              23              5  2213     11   7.22              0.31
# 285              19              7  3236     10  13.28              0.39
# 289              11              1  1081      9   6.14              0.54
# 290              26              8  2575     11  10.03              0.37
# 341              20             10  1867     10   9.43              0.48
# 344              28              3  2732     11   8.05              0.28
# 357              27              7  2570     13  11.09              0.41
# 359               3              0   280      2   2.36              0.80
# 360              29              0  2633     12   9.15              0.33
# 369              29              3  2747     10  10.12              0.35
# 389              17              9  1637     12   6.38              0.37
# 460              34              2  3313      9   9.42              0.27
# 471              33              0  3233     14  13.27              0.39
# 614               7              0   662      5   2.58              0.37
# 658              26              0  2461     15  14.51              0.56
#
#      Shots  OnTarget  Shots Per Avg Match  On Target Per Avg Match  Year
# 10      85        45                 3.26                     1.72  2016
# 51      84        45                 2.71                     1.45  2016
# 82      49        22                 2.08                     0.94  2016
# 83      44        21                 2.48                     1.18  2016
# 85      35        17                 1.65                     0.80  2016
# 89      64        34                 2.42                     1.29  2016
# 92      41        25                 2.76                     1.68  2016
# 96      50        23                 2.22                     1.02  2016
# 97      61        25                 2.89                     1.18  2016
# 98      37        17                 1.64                     0.75  2016
# 104     92        38                 3.16                     1.30  2017
# 149     55        26                 3.14                     1.48  2017
# 164     54        22                 2.86                     1.17  2017
# 171     45        23                 2.44                     1.25  2017
# 175     65        37                 2.50                     1.42  2017
# 176     88        34                 2.85                     1.10  2017
# 177     49        29                 3.01                     1.78  2017
# 178     75        25                 3.52                     1.17  2017
# 197     63        30                 3.22                     1.53  2018
# 216     70        30                 3.00                     1.29  2018
# 285     67        27                 1.97                     0.79  2018
# 289     42        20                 3.69                     1.76  2018
# 290     80        33                 2.95                     1.22  2018
# 341     55        21                 2.80                     1.07  2019
# 344     39        17                 1.36                     0.59  2019
# 357     53        23                 1.96                     0.85  2019
# 359      9         5                 3.05                     1.70  2019
# 360     69        36                 2.49                     1.30  2019
# 369     66        31                 2.28                     1.07  2019
# 389     46        20                 2.67                     1.16  2019
# 460     95        38                 2.72                     1.09  2019
# 471    116        39                 3.41                     1.15  2019
# 614     15         9                 2.15                     1.29  2020
# 658     84        43                 3.24                     1.66  2020

# %%
df = df.drop('Club', axis=1)

# %%
df
# Out:
#           Country      League       Player Names  Matches_Played  \
# 0           Spain     La Liga    Juanmi Callejon              19
# 1           Spain     La Liga  Antoine Griezmann              36
# 2           Spain     La Liga        Luis Suarez              34
# 3           Spain     La Liga       Ruben Castro              32
# 4           Spain     La Liga      Kevin Gameiro              21
# ..            ...         ...                ...             ...
# 655   Netherlands  Eredivisie        Gyrano Kerk              24
# 656   Netherlands  Eredivisie      Quincy Promes              18
# 657   Netherlands  Eredivisie    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    Cyriel Dessers               26
# 659   Netherlands  Eredivisie         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 0               16  1849     11   6.62              0.34     48        20
# 1                0  3129     16  11.86              0.36     88        41
# 2                1  2940     28  23.21              0.75    120        57
# 3                3  2842     13  14.06              0.47    117        42
# 4               10  1745     13  10.65              0.58     50        23
# ..             ...   ...    ...    ...               ...    ...       ...
# 655              0  2155     10   7.49              0.33     50        18
# 656              2  1573     12   9.77              0.59     56        30
# 657              0  2363      7   5.72              0.23     45        14
# 658              0  2461     15  14.51              0.56     84        43
# 659             11  1557      7   4.43              0.27     38        15
#
#      Shots Per Avg Match  On Target Per Avg Match  Year
# 0                   2.47                     1.03  2016
# 1                   2.67                     1.24  2016
# 2                   3.88                     1.84  2016
# 3                   3.91                     1.40  2016
# 4                   2.72                     1.25  2016
# ..                   ...                      ...   ...
# 655                 2.20                     0.79  2020
# 656                 3.38                     1.81  2020
# 657                 1.81                     0.56  2020
# 658                 3.24                     1.66  2020
# 659                 2.32                     0.92  2020
#
# [660 rows x 14 columns]

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                          Null Ratio %
# Country                           0.0
# League                            0.0
# Player Names                      0.0
# Matches_Played                    0.0
# Substitution                      0.0
# Mins                              0.0
# Goals                             0.0
# xG                                0.0
# xG Per Avg Match                  0.0
# Shots                             0.0
# OnTarget                          0.0
# Shots Per Avg Match               0.0
# On Target Per Avg Match           0.0
# Year                              0.0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, League, Player Names, Matches_Played, Substitution , Mins, Goals, xG, xG Per Avg Match, Shots, OnTarget, Shots Per Avg Match, On Target Per Avg Match, Year]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#           Country      League       Player Names  Matches_Played  \
# 0           Spain     La Liga    Juanmi Callejon              19
# 1           Spain     La Liga  Antoine Griezmann              36
# 2           Spain     La Liga        Luis Suarez              34
# 3           Spain     La Liga       Ruben Castro              32
# 4           Spain     La Liga      Kevin Gameiro              21
# ..            ...         ...                ...             ...
# 655   Netherlands  Eredivisie        Gyrano Kerk              24
# 656   Netherlands  Eredivisie      Quincy Promes              18
# 657   Netherlands  Eredivisie    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    Cyriel Dessers               26
# 659   Netherlands  Eredivisie         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 0               16  1849     11   6.62              0.34     48        20
# 1                0  3129     16  11.86              0.36     88        41
# 2                1  2940     28  23.21              0.75    120        57
# 3                3  2842     13  14.06              0.47    117        42
# 4               10  1745     13  10.65              0.58     50        23
# ..             ...   ...    ...    ...               ...    ...       ...
# 655              0  2155     10   7.49              0.33     50        18
# 656              2  1573     12   9.77              0.59     56        30
# 657              0  2363      7   5.72              0.23     45        14
# 658              0  2461     15  14.51              0.56     84        43
# 659             11  1557      7   4.43              0.27     38        15
#
#      Shots Per Avg Match  On Target Per Avg Match  Year
# 0                   2.47                     1.03  2016
# 1                   2.67                     1.24  2016
# 2                   3.88                     1.84  2016
# 3                   3.91                     1.40  2016
# 4                   2.72                     1.25  2016
# ..                   ...                      ...   ...
# 655                 2.20                     0.79  2020
# 656                 3.38                     1.81  2020
# 657                 1.81                     0.56  2020
# 658                 3.24                     1.66  2020
# 659                 2.32                     0.92  2020
#
# [660 rows x 14 columns]

# %%
df.describe()
# Out:
#        Matches_Played  Substitution          Mins       Goals          xG  \
# count      660.000000     660.000000   660.000000  660.000000  660.000000
# mean        22.371212       3.224242  2071.416667   11.784848   10.089606
# std          9.754658       3.839498   900.595049    5.982454    5.724844
# min          2.000000       0.000000   264.000000    2.000000    0.710000
# 25%         14.000000       0.000000  1363.500000    8.000000    6.100000
# 50%         24.000000       2.000000  2245.500000   11.000000    9.285000
# 75%         31.000000       5.000000  2822.000000   14.000000   13.252500
# max         38.000000      26.000000  4177.000000   37.000000   32.540000
#
#        xG Per Avg Match       Shots    OnTarget  Shots Per Avg Match  \
# count        660.000000  660.000000  660.000000           660.000000
# mean           0.476167   64.177273   28.365152             2.948015
# std            0.192831   34.941622   16.363149             0.914906
# min            0.070000    5.000000    2.000000             0.800000
# 25%            0.340000   37.750000   17.000000             2.335000
# 50%            0.435000   62.000000   26.000000             2.845000
# 75%            0.570000   86.000000   37.000000             3.382500
# max            1.350000  208.000000  102.000000             7.200000
#
#        On Target Per Avg Match         Year
# count               660.000000   660.000000
# mean                  1.315652  2018.363636
# std                   0.474239     1.367700
# min                   0.240000  2016.000000
# 25%                   0.980000  2017.000000
# 50%                   1.250000  2019.000000
# 75%                   1.540000  2019.000000
# max                   3.630000  2020.000000

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                    Persentase Outliers
# Matches_Played                           0.0
# Substitution                             0.0
# Mins                                     0.0
# Goals                                    0.0
# xG                                       0.0
# xG Per Avg Match                         0.0
# Shots                                    0.0
# OnTarget                                 0.0
# Shots Per Avg Match                      0.0
# On Target Per Avg Match                  0.0
# Year                                     0.0

# %%
df
# Out:
#           Country      League       Player Names  Matches_Played  \
# 0           Spain     La Liga    Juanmi Callejon              19
# 1           Spain     La Liga  Antoine Griezmann              36
# 2           Spain     La Liga        Luis Suarez              34
# 3           Spain     La Liga       Ruben Castro              32
# 4           Spain     La Liga      Kevin Gameiro              21
# ..            ...         ...                ...             ...
# 655   Netherlands  Eredivisie        Gyrano Kerk              24
# 656   Netherlands  Eredivisie      Quincy Promes              18
# 657   Netherlands  Eredivisie    Denzel Dumfries              25
# 658   Netherlands  Eredivisie    Cyriel Dessers               26
# 659   Netherlands  Eredivisie         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 0               16  1849     11   6.62              0.34     48        20
# 1                0  3129     16  11.86              0.36     88        41
# 2                1  2940     28  23.21              0.75    120        57
# 3                3  2842     13  14.06              0.47    117        42
# 4               10  1745     13  10.65              0.58     50        23
# ..             ...   ...    ...    ...               ...    ...       ...
# 655              0  2155     10   7.49              0.33     50        18
# 656              2  1573     12   9.77              0.59     56        30
# 657              0  2363      7   5.72              0.23     45        14
# 658              0  2461     15  14.51              0.56     84        43
# 659             11  1557      7   4.43              0.27     38        15
#
#      Shots Per Avg Match  On Target Per Avg Match  Year
# 0                   2.47                     1.03  2016
# 1                   2.67                     1.24  2016
# 2                   3.88                     1.84  2016
# 3                   3.91                     1.40  2016
# 4                   2.72                     1.25  2016
# ..                   ...                      ...   ...
# 655                 2.20                     0.79  2020
# 656                 3.38                     1.81  2020
# 657                 1.81                     0.56  2020
# 658                 3.24                     1.66  2020
# 659                 2.32                     0.92  2020
#
# [660 rows x 14 columns]

# %%
columns_to_impute = ["Matches_Played", "Substitution ", "Mins", "Goals", "xG",
                     "xG Per Avg Match", "Shots", "OnTarget", "Shots Per Avg Match",
                     "On Target Per Avg Match", "Year"]

for col in columns_to_impute:
    if col in df.columns and pd.api.types.is_numeric_dtype(df[col]):  # Cek apakah kolom ada & numerik
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Menggunakan clip untuk menangani outliers
        df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)
    else:
        print(f"Kolom '{col}' tidak ditemukan atau bukan numerik.")

print("Outliers telah ditangani menggunakan metode IQR!")
# Out:
# Outliers telah ditangani menggunakan metode IQR!

# %%
df["Goal_per_90_minutes"] = df["Goals"] / df["Mins"] * 90

print(df.head())
# Out:
#   Country   League       Player Names  Matches_Played  Substitution   Mins  \
# 0   Spain  La Liga    Juanmi Callejon              19           12.5  1849
# 1   Spain  La Liga  Antoine Griezmann              36            0.0  3129
# 2   Spain  La Liga        Luis Suarez              34            1.0  2940
# 3   Spain  La Liga       Ruben Castro              32            3.0  2842
# 4   Spain  La Liga      Kevin Gameiro              21           10.0  1745
#
#    Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0     11   6.62              0.34   48.0        20                 2.47
# 1     16  11.86              0.36   88.0        41                 2.67
# 2     23  23.21              0.75  120.0        57                 3.88
# 3     13  14.06              0.47  117.0        42                 3.91
# 4     13  10.65              0.58   50.0        23                 2.72
#
#    On Target Per Avg Match  Year  Goal_per_90_minutes
# 0                     1.03  2016             0.535425
# 1                     1.24  2016             0.460211
# 2                     1.84  2016             0.704082
# 3                     1.40  2016             0.411682
# 4                     1.25  2016             0.670487

# %%
df["Shot_Accuracy (%)"] = df["OnTarget"] / df["Shots"] * 100

print(df.head())
# Out:
#   Country   League       Player Names  Matches_Played  Substitution   Mins  \
# 0   Spain  La Liga    Juanmi Callejon              19           12.5  1849
# 1   Spain  La Liga  Antoine Griezmann              36            0.0  3129
# 2   Spain  La Liga        Luis Suarez              34            1.0  2940
# 3   Spain  La Liga       Ruben Castro              32            3.0  2842
# 4   Spain  La Liga      Kevin Gameiro              21           10.0  1745
#
#    Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0     11   6.62              0.34   48.0        20                 2.47
# 1     16  11.86              0.36   88.0        41                 2.67
# 2     23  23.21              0.75  120.0        57                 3.88
# 3     13  14.06              0.47  117.0        42                 3.91
# 4     13  10.65              0.58   50.0        23                 2.72
#
#    On Target Per Avg Match  Year  Goal_per_90_minutes  Shot_Accuracy (%)
# 0                     1.03  2016             0.535425          41.666667
# 1                     1.24  2016             0.460211          46.590909
# 2                     1.84  2016             0.704082          47.500000
# 3                     1.40  2016             0.411682          35.897436
# 4                     1.25  2016             0.670487          46.000000

# %%
df["Conversion_rate (%)"] = df["Goals"] / df["Shots"] * 100

print(df.head())
# Out:
#   Country   League       Player Names  Matches_Played  Substitution   Mins  \
# 0   Spain  La Liga    Juanmi Callejon              19           12.5  1849
# 1   Spain  La Liga  Antoine Griezmann              36            0.0  3129
# 2   Spain  La Liga        Luis Suarez              34            1.0  2940
# 3   Spain  La Liga       Ruben Castro              32            3.0  2842
# 4   Spain  La Liga      Kevin Gameiro              21           10.0  1745
#
#    Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0     11   6.62              0.34   48.0        20                 2.47
# 1     16  11.86              0.36   88.0        41                 2.67
# 2     23  23.21              0.75  120.0        57                 3.88
# 3     13  14.06              0.47  117.0        42                 3.91
# 4     13  10.65              0.58   50.0        23                 2.72
#
#    On Target Per Avg Match  Year  Goal_per_90_minutes  Shot_Accuracy (%)  \
# 0                     1.03  2016             0.535425          41.666667
# 1                     1.24  2016             0.460211          46.590909
# 2                     1.84  2016             0.704082          47.500000
# 3                     1.40  2016             0.411682          35.897436
# 4                     1.25  2016             0.670487          46.000000
#
#    Conversion_rate (%)
# 0            22.916667
# 1            18.181818
# 2            19.166667
# 3            11.111111
# 4            26.000000

# %%
df["xG_difference"] = df["Goals"] / df["xG"] * 100

print(df.head())
# Out:
#   Country   League       Player Names  Matches_Played  Substitution   Mins  \
# 0   Spain  La Liga    Juanmi Callejon              19           12.5  1849
# 1   Spain  La Liga  Antoine Griezmann              36            0.0  3129
# 2   Spain  La Liga        Luis Suarez              34            1.0  2940
# 3   Spain  La Liga       Ruben Castro              32            3.0  2842
# 4   Spain  La Liga      Kevin Gameiro              21           10.0  1745
#
#    Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0     11   6.62              0.34   48.0        20                 2.47
# 1     16  11.86              0.36   88.0        41                 2.67
# 2     23  23.21              0.75  120.0        57                 3.88
# 3     13  14.06              0.47  117.0        42                 3.91
# 4     13  10.65              0.58   50.0        23                 2.72
#
#    On Target Per Avg Match  Year  Goal_per_90_minutes  Shot_Accuracy (%)  \
# 0                     1.03  2016             0.535425          41.666667
# 1                     1.24  2016             0.460211          46.590909
# 2                     1.84  2016             0.704082          47.500000
# 3                     1.40  2016             0.411682          35.897436
# 4                     1.25  2016             0.670487          46.000000
#
#    Conversion_rate (%)  xG_difference
# 0            22.916667     166.163142
# 1            18.181818     134.907251
# 2            19.166667      99.095218
# 3            11.111111      92.460882
# 4            26.000000     122.065728

# %%
df = df.drop('Country', axis=1)
df
# Out:
#          League       Player Names  Matches_Played  Substitution   Mins  \
# 0       La Liga    Juanmi Callejon              19           12.5  1849
# 1       La Liga  Antoine Griezmann              36            0.0  3129
# 2       La Liga        Luis Suarez              34            1.0  2940
# 3       La Liga       Ruben Castro              32            3.0  2842
# 4       La Liga      Kevin Gameiro              21           10.0  1745
# ..          ...                ...             ...            ...   ...
# 655  Eredivisie        Gyrano Kerk              24            0.0  2155
# 656  Eredivisie      Quincy Promes              18            2.0  1573
# 657  Eredivisie    Denzel Dumfries              25            0.0  2363
# 658  Eredivisie    Cyriel Dessers               26            0.0  2461
# 659  Eredivisie         Cody Gakpo              14           11.0  1557
#
#      Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0       11   6.62              0.34   48.0        20                 2.47
# 1       16  11.86              0.36   88.0        41                 2.67
# 2       23  23.21              0.75  120.0        57                 3.88
# 3       13  14.06              0.47  117.0        42                 3.91
# 4       13  10.65              0.58   50.0        23                 2.72
# ..     ...    ...               ...    ...       ...                  ...
# 655     10   7.49              0.33   50.0        18                 2.20
# 656     12   9.77              0.59   56.0        30                 3.38
# 657      7   5.72              0.23   45.0        14                 1.81
# 658     15  14.51              0.56   84.0        43                 3.24
# 659      7   4.43              0.27   38.0        15                 2.32
#
#      On Target Per Avg Match  Year  Goal_per_90_minutes  Shot_Accuracy (%)  \
# 0                       1.03  2016             0.535425          41.666667
# 1                       1.24  2016             0.460211          46.590909
# 2                       1.84  2016             0.704082          47.500000
# 3                       1.40  2016             0.411682          35.897436
# 4                       1.25  2016             0.670487          46.000000
# ..                       ...   ...                  ...                ...
# 655                     0.79  2020             0.417633          36.000000
# 656                     1.81  2020             0.686586          53.571429
# 657                     0.56  2020             0.266610          31.111111
# 658                     1.66  2020             0.548557          51.190476
# 659                     0.92  2020             0.404624          39.473684
#
#      Conversion_rate (%)  xG_difference
# 0              22.916667     166.163142
# 1              18.181818     134.907251
# 2              19.166667      99.095218
# 3              11.111111      92.460882
# 4              26.000000     122.065728
# ..                   ...            ...
# 655            20.000000     133.511348
# 656            21.428571     122.824974
# 657            15.555556     122.377622
# 658            17.857143     103.376981
# 659            18.421053     158.013544
#
# [660 rows x 17 columns]

# %%
df = df.drop('Substitution ', axis=1)
df
# Out:
#          League       Player Names  Matches_Played  Mins  Goals     xG  \
# 0       La Liga    Juanmi Callejon              19  1849     11   6.62
# 1       La Liga  Antoine Griezmann              36  3129     16  11.86
# 2       La Liga        Luis Suarez              34  2940     23  23.21
# 3       La Liga       Ruben Castro              32  2842     13  14.06
# 4       La Liga      Kevin Gameiro              21  1745     13  10.65
# ..          ...                ...             ...   ...    ...    ...
# 655  Eredivisie        Gyrano Kerk              24  2155     10   7.49
# 656  Eredivisie      Quincy Promes              18  1573     12   9.77
# 657  Eredivisie    Denzel Dumfries              25  2363      7   5.72
# 658  Eredivisie    Cyriel Dessers               26  2461     15  14.51
# 659  Eredivisie         Cody Gakpo              14  1557      7   4.43
#
#      xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0                0.34   48.0        20                 2.47
# 1                0.36   88.0        41                 2.67
# 2                0.75  120.0        57                 3.88
# 3                0.47  117.0        42                 3.91
# 4                0.58   50.0        23                 2.72
# ..                ...    ...       ...                  ...
# 655              0.33   50.0        18                 2.20
# 656              0.59   56.0        30                 3.38
# 657              0.23   45.0        14                 1.81
# 658              0.56   84.0        43                 3.24
# 659              0.27   38.0        15                 2.32
#
#      On Target Per Avg Match  Year  Goal_per_90_minutes  Shot_Accuracy (%)  \
# 0                       1.03  2016             0.535425          41.666667
# 1                       1.24  2016             0.460211          46.590909
# 2                       1.84  2016             0.704082          47.500000
# 3                       1.40  2016             0.411682          35.897436
# 4                       1.25  2016             0.670487          46.000000
# ..                       ...   ...                  ...                ...
# 655                     0.79  2020             0.417633          36.000000
# 656                     1.81  2020             0.686586          53.571429
# 657                     0.56  2020             0.266610          31.111111
# 658                     1.66  2020             0.548557          51.190476
# 659                     0.92  2020             0.404624          39.473684
#
#      Conversion_rate (%)  xG_difference
# 0              22.916667     166.163142
# 1              18.181818     134.907251
# 2              19.166667      99.095218
# 3              11.111111      92.460882
# 4              26.000000     122.065728
# ..                   ...            ...
# 655            20.000000     133.511348
# 656            21.428571     122.824974
# 657            15.555556     122.377622
# 658            17.857143     103.376981
# 659            18.421053     158.013544
#
# [660 rows x 16 columns]

# %%
df = df.drop('League', axis=1)
df
# Out:
#           Player Names  Matches_Played  Mins  Goals     xG  xG Per Avg Match  \
# 0      Juanmi Callejon              19  1849     11   6.62              0.34
# 1    Antoine Griezmann              36  3129     16  11.86              0.36
# 2          Luis Suarez              34  2940     23  23.21              0.75
# 3         Ruben Castro              32  2842     13  14.06              0.47
# 4        Kevin Gameiro              21  1745     13  10.65              0.58
# ..                 ...             ...   ...    ...    ...               ...
# 655        Gyrano Kerk              24  2155     10   7.49              0.33
# 656      Quincy Promes              18  1573     12   9.77              0.59
# 657    Denzel Dumfries              25  2363      7   5.72              0.23
# 658    Cyriel Dessers               26  2461     15  14.51              0.56
# 659         Cody Gakpo              14  1557      7   4.43              0.27
#
#      Shots  OnTarget  Shots Per Avg Match  On Target Per Avg Match  Year  \
# 0     48.0        20                 2.47                     1.03  2016
# 1     88.0        41                 2.67                     1.24  2016
# 2    120.0        57                 3.88                     1.84  2016
# 3    117.0        42                 3.91                     1.40  2016
# 4     50.0        23                 2.72                     1.25  2016
# ..     ...       ...                  ...                      ...   ...
# 655   50.0        18                 2.20                     0.79  2020
# 656   56.0        30                 3.38                     1.81  2020
# 657   45.0        14                 1.81                     0.56  2020
# 658   84.0        43                 3.24                     1.66  2020
# 659   38.0        15                 2.32                     0.92  2020
#
#      Goal_per_90_minutes  Shot_Accuracy (%)  Conversion_rate (%)  \
# 0               0.535425          41.666667            22.916667
# 1               0.460211          46.590909            18.181818
# 2               0.704082          47.500000            19.166667
# 3               0.411682          35.897436            11.111111
# 4               0.670487          46.000000            26.000000
# ..                   ...                ...                  ...
# 655             0.417633          36.000000            20.000000
# 656             0.686586          53.571429            21.428571
# 657             0.266610          31.111111            15.555556
# 658             0.548557          51.190476            17.857143
# 659             0.404624          39.473684            18.421053
#
#      xG_difference
# 0       166.163142
# 1       134.907251
# 2        99.095218
# 3        92.460882
# 4       122.065728
# ..             ...
# 655     133.511348
# 656     122.824974
# 657     122.377622
# 658     103.376981
# 659     158.013544
#
# [660 rows x 15 columns]
